# %%
# @title Установка Среды.
from pathlib import Path
import os

lang, branch = 'ru', 'dev'
scripts_dir = Path.home() / 'ANXETY' / 'scripts'
out = scripts_dir / lang / f'setup-{lang}.py'

os.makedirs(out.parent, exist_ok=True)
# !curl -sLo {out} https://raw.githubusercontent.com/anxety-solo/sdAIgen/{branch}/scripts/{lang}/setup-{lang}.py

# %run $out --lang=$lang --branch=$branch

# %% [markdown]
# ---
# ## 1. Виджеты 🔽

# %%
# Выбор моделей, vae, control-net и прочее.

# %run $scripts_dir/$lang/widgets-{lang}.py
# Out:
# <style>/* General Styles */
#
# @import url('https://fonts.googleapis.com/css2?family=Shantell+Sans:ital,wght@0,300..800;1,300..800&family=Tiny5&display=swap');
#
# .header {
#     display: inline-block;
#     font-family: cursive;
#     font-size: 20px;
#     font-weight: 900;
#     color: #FF97EF;
#     margin-bottom: 15px;
#     user-select: none;
#     cursor: default;
#     text-shadow: 0 0 10px rgba(255, 255, 255, 0.15);
# }
#
# hr {
#     border-color: grey;
#     background-color: grey;
#     opacity: 0.25;
# }
#
# a {
#     color: inherit;
#     text-decoration: none;
# }
#
# /* Container style */
#
# .container {
#     position: relative;
#     padding: 10px 15px;
#     margin: 5px 0 0 5px;
#     background-color: #232323;
#     border: 2px solid rgba(0, 0, 0, 0.4);
#     border-radius: 15px;
#     box-shadow: 0 0 15px rgba(0, 0, 0, 0.35), inset 0 0 10px rgba(0, 0, 0, 0.3);
#     overflow: hidden;
# }
# .container::after {
#     position: absolute;
#     top: 5px;
# ...

# %% [markdown]
# ## 2. Загрузка 🔽

# %%
# Загрузка библиотек, репо, моделей и прочего.

# %run $scripts_dir/$lang/downloading-{lang}.py

# %% [markdown]
# ## 3. Запуск 🔽

# %%
# Запустить WebUI.

# %run $scripts_dir/launch.py

# %% [markdown]
# ---
# # Утилиты

# %%
# Запустить AutoCleaner.

# %run $scripts_dir/auto-cleaner.py
